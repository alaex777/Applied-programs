# %%
# Задание 1.1

x = var('x')
f(x) = exp(10*sqrt(x))*(x^2)

F(x) = integral(f(x), x)
const = 0 - F(0)
show(plot((f(x), derivative(f(x), x), F(x) + const), 0, 1))
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
a = 1
b = 1.5

print('Max:', f(max(a, b, f)))
print('Min:', f(min(a, b, f)))
print('Limit:', limit(f, x=(a+b)/2))
print('Taylor: ', f.taylor(x, (a+b)/3, 7))
# Out:
# Max: 469009.794090347
# Min: e^10
# Limit: x |--> 112041.76584871791
# Taylor:  x |--> 247189.7836782386*(x - 0.8333333333333334)^7 + 421416.4750865072*(x - 0.8333333333333334)^6 + 552840.0099660024*(x - 0.8333333333333334)^5 + 541381.4932552034*(x - 0.8333333333333334)^4 + 379624.938191213*(x - 0.8333333333333334)^3 + 178832.220226216*(x - 0.8333333333333334)^2 + 50414.89447278179*x - 35612.32944368883

# %%
# Задание 1.2

A = random_matrix(ZZ, 9, 9)

print('Matrix: \n', A)
print('Det: ', det(A))
print('Rank: ', rank(A))
print('Kernel: ', A.kernel())
print('Eigenvalues: ', A.eigenvalues())
# Out:
# Matrix:
#  [  -2  -10    1   -1    1   -1   -6    0    0]
# [   0   -1   -2    0    2   -2   19   -2   11]
# [  -5    1 -112    1    1    1    1    6   -2]
# [  -1    0   -3   -1   -3    0   -1   -1    1]
# [  -2   -2   -4   14   -1   -2    2    7    6]
# [   1    0    0    2   -3    0    3  -28    1]
# [   0    1   -1   -1   -2    7   11    6   -1]
# [   9    0    0   -1    9   -1    0    1    0]
# [   3   -4    0    2  -18   -7    2   -1   -2]
# Det:  39843981455
# Rank:  9
# Kernel:  Free module of degree 9 and rank 0 over Integer Ring
# Echelon basis matrix:
# []
# Eigenvalues:  [-111.9007421141328?, -8.438106167354145?, 17.48687218373389?, -6.525410725149195? - 9.06637491683129?*I, -6.525410725149195? + 9.06637491683129?*I, -2.776091396691974? - 11.37944063057772?*I, -2.776091396691974? + 11.37944063057772?*I, 7.227490170717698? - 9.419005766153334?*I, 7.227490170717698? + 9.419005766153334?*I]

# %%
b = random_matrix(ZZ, 9, 1)
print('Rand vect: ', b)
print('Solve Ax = b: ', A.solve_right(b))
# Out:
# Rand vect:  [ -1]
# [  0]
# [  2]
# [  1]
# [  1]
# [-27]
# [  0]
# [ -1]
# [ -9]
# Solve Ax = b:  [-16507138841/39843981455]
# [ 20442911789/39843981455]
# [  1098025573/39843981455]
# [-26386481317/39843981455]
# [  4604705227/39843981455]
# [ -5914631396/39843981455]
# [  -3118900508/7968796291]
# [ 34976808358/39843981455]
# [   6688171903/7968796291]
